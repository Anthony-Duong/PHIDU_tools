# %%
from PHIDU_parser import PHIDU_parse

# %% [markdown]
# This is a test of the code for PHIDU predictive model using only the youth dataset from 2021 to both train and test the data and evaluate the model.

# %%
file = '2021_data.xlsx'

# %%
data_2021 = PHIDU_parse(file)

# %%
data_2021.dataset
# Out:
#     LGA_code % children aged 4 years old enrolled in a preschool program  \
# 4     PHN101                                          75.260729
# 5      11100                                          74.319121
# 6      11300                                          68.250797
# 7      11520                                          80.988208
# 8     11570a                                          67.078633
# ..       ...                                                ...
# 591    74660                                          24.038678
# 592    74680                                           7.901398
# 593    79399                                          77.048552
# 594   PHN801                                          92.240791
# 595    89399                                          92.411323
#
#     % children aged 5 years old enrolled in a preschool program  \
# 4                                            18.241303
# 5                                            14.451577
# 6                                            13.711467
# 7                                            16.359602
# 8                                            11.215103
# ..                                                 ...
# 591                                           3.316165
# 592                                                  0
# 593                                           8.036349
# 594                                          27.437794
# 595                                          27.320108
#
#     % children aged 4 and 5 years old enrolled in a preschool program  \
# 4                                            47.786617
# 5                                            45.814409
# 6                                            40.007972
# 7                                            49.325707
# 8                                            40.295248
# ..                                                 ...
# 591                                           12.02036
# 592                                            3.19735
# 593                                          38.326989
# 594                                          59.608872
# 595                                           59.63427
#
#      % full-time participation at age 16 % in higher education  \
# 4                              87.484045             41.395253
# 5                              88.503254             45.425162
# 6                              88.770053             45.493501
# 7                              91.709184             51.416118
# 8                              84.626071             43.746221
# ..                                   ...                   ...
# 591                            40.983607                   NaN
# 592                            44.927536                     0
# 593                            69.387755                   NaN
# 594                            88.901628             24.162718
# 595                            88.955224             24.567494
#
#      % single parent families  % jobless families  \
# 4                   15.122891            7.673360
# 5                   16.222655            8.163707
# 6                   15.745856            9.254144
# 7                   13.256723            6.137441
# 8                   18.143863           16.394292
# ..                        ...                 ...
# 591                 22.965879           45.740498
# 592                 29.453682           56.775701
# 593                 13.314038            2.741703
# 594                 16.655438            6.262932
# 595                 16.655438            6.262932
#
#      % children in jobless families  \
# 4                          7.005612
# 5                          7.804449
# 6                          8.470395
# 7                          5.380853
# 8                         16.139400
# ..                              ...
# 591                       35.816619
# 592                       50.928641
# 593                        2.734148
# 594                        6.201405
# 595                        6.201405
#
#      % children in families where the mother has low educational attainment  \
# 4                                             9.965388
# 5                                            11.474174
# 6                                             8.141447
# 7                                             7.428372
# 8                                            18.691051
# ..                                                 ...
# 591                                          34.269341
# 592                                          59.530792
# 593                                          10.994764
# 594                                           9.401308
# 595                                           9.401308
#
#      ...  % Children developmentally vulnerable in physical domain  \
# 4    ...                                           7.002465
# 5    ...                                           8.430913
# 6    ...                                           9.337349
# 7    ...                                           4.564315
# 8    ...                                           8.920287
# ..   ...                                                ...
# 591  ...                                                NaN
# 592  ...                                          46.551724
# 593  ...                                          14.606742
# 594  ...                                          12.144420
# 595  ...                                          12.144420
#
#      % Children developmentally at risk in physical domain  \
# 4                                            12.265974
# 5                                            17.564403
# 6                                            16.566265
# 7                                             9.958506
# 8                                            13.264445
# ..                                                 ...
# 591                                                NaN
# 592                                          27.586207
# 593                                          19.101124
# 594                                          17.833698
# 595                                          17.833698
#
#      % Children developmentally vulnerable in social domain  \
# 4                                             7.941902
# 5                                            11.241218
# 6                                            12.650602
# 7                                             6.535270
# 8                                            11.054852
# ..                                                 ...
# 591                                                NaN
# 592                                          67.241379
# 593                                          15.730337
# 594                                          12.290299
# 595                                          12.290299
#
#      % Children developmentally at risk in social domain  \
# 4                                            12.639083
# 5                                            13.114754
# 6                                            13.253012
# 7                                             9.336100
# 8                                            14.092827
# ..                                                 ...
# 591                                                NaN
# 592                                          17.241379
# 593                                          14.606742
# 594                                          15.335522
# 595                                          15.335522
#
#      % Children developmentally vulnerable in emotional domain  \
# 4                                             5.599089
# 5                                             8.196721
# 6                                             8.510638
# 7                                             5.601660
# 8                                             5.623939
# ..                                                 ...
# 591                                                NaN
# 592                                          48.275862
# 593                                          13.483146
# 594                                           9.908759
# 595                                           9.908759
#
#      % Children developmentally at risk in emotional domain  \
# 4                                            11.934901
# 5                                            10.538642
# 6                                            19.148936
# 7                                             8.817427
# 8                                            12.882003
# ..                                                 ...
# 591                                                NaN
# 592                                          18.965517
# 593                                          10.112360
# 594                                          13.941606
# 595                                          13.941606
#
#      % Children developmentally vulnerable in language and cognitive domain  \
# 4                                             3.638060
# 5                                             4.672897
# 6                                             6.927711
# 7                                             2.489627
# 8                                             6.900190
# ..                                                 ...
# 591                                                NaN
# 592                                          63.793103
# 593                                           7.865169
# 594                                           6.424530
# 595                                           6.424530
#
#      % Children developmentally at risk in language and cognitive domain  \
# 4                                             6.123401
# 5                                             7.476636
# 6                                             9.036145
# 7                                             3.526971
# 8                                             8.419498
# ..                                                 ...
# 591                                                NaN
# 592                                          29.310345
# 593                                          11.235955
# 594                                           9.381274
# 595                                           9.381274
#
#      % Children developmentally vulnerable in communication domain  \
# 4                                             7.282783
# 5                                             8.430913
# 6                                            15.963855
# 7                                             6.639004
# 8                                            12.658228
# ..                                                 ...
# 591                                                NaN
# 592                                          63.793103
# 593                                           7.865169
# 594                                           7.786287
# 595                                           7.786287
#
#      % Children developmentally at risk in communication domain
# 4                                            14.205757
# 5                                            18.969555
# 6                                            14.759036
# 7                                            12.448133
# 8                                            17.004219
# ..                                                 ...
# 591                                                NaN
# 592                                          22.413793
# 593                                          14.606742
# 594                                          19.748359
# 595                                          19.748359
#
# [592 rows x 113 columns]

# %% [markdown]
# ## Exploratory Analysis

# %%
data_2021.data['AEDC'].sort_values('% Children developmentally vulnerable on one or more domains', ascending = False).head(10)
# Out:
# 3   LGA_code  % Children developmentally vulnerable on one or more domains  \
# 319    35670                                          89.473684
# 588    74050                                          78.260870
# 592    74680                                          77.586207
# 579    70620                                          71.428571
# 587    73600                                          70.873786
# 483    53920                                          70.312500
# 256    32330                                          69.230769
# 577    70420                                          64.893617
# 299    37550                                          62.068966
# 326    36960                                          61.956522
#
# 3    % Children developmentally vulnerable on two or more domains  \
# 319                                          78.947368
# 588                                          60.869565
# 592                                          72.413793
# 579                                          54.285714
# 587                                          56.862745
# 483                                          50.000000
# 256                                          50.000000
# 577                                          53.191489
# 299                                          44.827586
# 326                                          40.217391
#
# 3    % Children developmentally vulnerable in physical domain  \
# 319                                          78.947368
# 588                                          47.826087
# 592                                          46.551724
# 579                                          37.142857
# 587                                          38.834951
# 483                                          31.250000
# 256                                          26.923077
# 577                                          45.744681
# 299                                          37.931034
# 326                                          25.806452
#
# 3    % Children developmentally at risk in physical domain  \
# 319                                           5.263158
# 588                                          21.739130
# 592                                          27.586207
# 579                                          28.571429
# 587                                          19.417476
# 483                                          34.375000
# 256                                          19.230769
# 577                                           8.510638
# 299                                          17.241379
# 326                                          19.354839
#
# 3    % Children developmentally vulnerable in social domain  \
# 319                                          63.157895
# 588                                          22.727273
# 592                                          67.241379
# 579                                          41.428571
# 587                                          35.922330
# 483                                          39.062500
# 256                                          38.461538
# 577                                          38.297872
# 299                                          41.379310
# 326                                          32.258065
#
# 3    % Children developmentally at risk in social domain  \
# 319                                          31.578947
# 588                                          27.272727
# 592                                          17.241379
# 579                                          18.571429
# 587                                          22.330097
# 483                                          29.687500
# 256                                          19.230769
# 577                                          22.340426
# 299                                          27.586207
# 326                                          26.881720
#
# 3    % Children developmentally vulnerable in emotional domain  \
# 319                                          42.105263
# 588                                          33.333333
# 592                                          48.275862
# 579                                          38.571429
# 587                                          33.000000
# 483                                          32.812500
# 256                                          53.846154
# 577                                          29.787234
# 299                                          48.275862
# 326                                          23.595506
#
# 3    % Children developmentally at risk in emotional domain  \
# 319                                          26.315789
# 588                                          28.571429
# 592                                          18.965517
# 579                                          21.428571
# 587                                          14.000000
# 483                                          21.875000
# 256                                          19.230769
# 577                                          20.212766
# 299                                          31.034483
# 326                                          30.337079
#
# 3    % Children developmentally vulnerable in language and cognitive domain  \
# 319                                          68.421053
# 588                                          28.571429
# 592                                          63.793103
# 579                                          64.285714
# 587                                          50.000000
# 483                                          54.687500
# 256                                          19.230769
# 577                                          56.382979
# 299                                          34.482759
# 326                                          20.652174
#
# 3    % Children developmentally at risk in language and cognitive domain  \
# 319                                          15.789474
# 588                                          57.142857
# 592                                          29.310345
# 579                                          14.285714
# 587                                          24.509804
# 483                                          26.562500
# 256                                          23.076923
# 577                                          13.829787
# 299                                           6.896552
# 326                                          27.173913
#
# 3    % Children developmentally vulnerable in communication domain  \
# 319                                          78.947368
# 588                                          56.521739
# 592                                          63.793103
# 579                                          48.571429
# 587                                          40.384615
# 483                                          25.000000
# 256                                          19.230769
# 577                                          40.425532
# 299                                          20.689655
# 326                                          43.478261
#
# 3    % Children developmentally at risk in communication domain
# 319                                           5.263158
# 588                                           8.695652
# 592                                          22.413793
# 579                                          14.285714
# 587                                          24.038462
# 483                                          50.000000
# 256                                           3.846154
# 577                                          22.340426
# 299                                          20.689655
# 326                                          31.521739

# %% [markdown]
# Many of the top top most at risk children are living in the NT or Northern Queensland. However, due to a low population, assessed, less than 20 students in most of these cases, the data is not of the highest quality to compare to between LGAs across PHNs, therefore comparisions will only be done between PHNs before exploding the data and analysing between LGAs if needed

# %%
AEDC_2021 = data_2021.data['AEDC'].sort_values('% Children developmentally vulnerable on one or more domains', ascending = False)
AEDC_2021 = AEDC_2021.dropna()
AEDC_2021 = AEDC_2021[AEDC_2021['LGA_code'].str.startswith('PHN')]

AEDC_2021
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 AEDC_2021 = data_2021.data['AEDC'].sort_values('% Children developmentally vulnerable on one or more domains', ascending = False)
#       2 AEDC_2021 = AEDC_2021.dropna()
# ----> 3 AEDC_2021 = AEDC_2021[AEDC_2021['LGA_code'].str.startswith('PHN')]
#       5 AEDC_2021
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
#     131         # Don't raise on e.g. ["A", "B", np.nan], see
#     132         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 133         raise ValueError(na_msg)
#     134     return False
#     135 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values
